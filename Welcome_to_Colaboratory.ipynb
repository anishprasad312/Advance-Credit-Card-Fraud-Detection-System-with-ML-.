# %% [markdown]
# <a href="https://colab.research.google.com/github/anishprasad312/Advance-Credit-Card-Fraud-Detection-System-with-ML-./blob/main/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <!-- TODO(b/319266067) remove temporary advert after a few weeks. -->
# <div class="markdown-google-sans">
#   <h2>&#40;New&#41; Try the Gemini API</h2>
#   <ul>
#   <li><a href="https://makersuite.google.com/app/apikey">Generate a Gemini API key</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/google/generative-ai-docs/blob/main/site/en/tutorials/python_quickstart.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API: Quickstart with Python</a></li>
#   <li><a href="https://colab.research.google.com/notebooks/snippets/gemini.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API code sample</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %% [markdown]
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing three cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or ‘Colaboratory’, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a <strong>student</strong>, a <strong>data scientist</strong> or an <strong>AI researcher</strong>, Colab can make your work easier. Watch <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introduction to Colab</a> to find out more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Getting started</strong>
# </div>
#
# The document that you are reading is not a static web page, but an interactive environment called a <strong>Colab notebook</strong> that lets you write and execute code.
#
# For example, here is a <strong>code cell</strong> with a short Python script that computes a value, stores it in a variable and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut 'Command/Ctrl+Enter'. To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine <strong>executable code</strong> and <strong>rich text</strong> in a single document, along with <strong>images</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To find out more, see <a href="/notebooks/basic_features_overview.ipynb">Overview of Colab</a>. To create a new Colab notebook you can use the File menu above, or use the following link: <a href="http://colab.research.google.com#create=true">Create a new Colab notebook</a>.
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To find out more about the Jupyter project, see <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyse and visualise data. The code cell below uses <strong>numpy</strong> to generate some random data, and uses <strong>matplotlib</strong> to visualise it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from GitHub and many other sources. To find out more about importing data, and how Colab can be used for data science, see the links below under <a href="#working-with-data">Working with data</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">a few lines of code</a>. Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including <a href="#using-accelerated-hardware">GPUs and TPUs</a>, regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the <a href="#machine-learning-examples">machine learning examples</a> below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More resources
#
# ### Working with notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with data
# </div>
#
# - [Loading data: Drive, Sheets and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualising data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine learning crash course
#
# <div>
#
# These are a few of the notebooks from Google's online machine learning course. See the <a href="https://developers.google.com/machine-learning/crash-course/">full course website</a> for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using accelerated hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo voice swap</a>: Use Nvidia NeMo conversational AI toolkit to swap a voice in an audio fragment with a computer-generated one.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Retraining an Image Classifier</a>: Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Text Classification</a>: Classify IMDB film reviews as either <em>positive</em> or <em>negative</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Style Transfer</a>: Use deep learning to transfer style between images.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Multilingual Universal Sentence Encoder Q&amp;A</a>: Use a machine-learning model to answer questions from the SQuAD dataset.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Video Interpolation</a>: Predict what happened in a video between the first and the last frame.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, MaxPool1D
from tensorflow.keras.optimizers import Adam
print(tf.__version__)
# Out:
# 2.15.0

# %%
import pandas as pd
import numpy as np
import  seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (1986, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1986 non-null   int64
#  1   V1      1986 non-null   float64
#  2   V2      1986 non-null   float64
#  3   V3      1986 non-null   float64
#  4   V4      1986 non-null   float64
#  5   V5      1986 non-null   float64
#  6   V6      1986 non-null   float64
#  7   V7      1986 non-null   float64
#  8   V8      1986 non-null   float64
#  9   V9      1986 non-null   float64
#  10  V10     1986 non-null   float64
#  11  V11     1986 non-null   float64
#  12  V12     1986 non-null   float64
#  13  V13     1986 non-null   float64
#  14  V14     1985 non-null   float64
#  15  V15     1985 non-null   float64
#  16  V16     1985 non-null   float64
#  17  V17     1985 non-null   float64
#  18  V18     1985 non-null   float64
#  19  V19     1985 non-null   float64
#  20  V20     1985 non-null   float64
#  21  V21     1985 non-null   float64
#  22  V22     1985 non-null   float64
#  23  V23     1985 non-null   float64
#  24  V24     1985 non-null   float64
#  25  V25     1985 non-null   float64
#  26  V26     1985 non-null   float64
#  27  V27     1985 non-null   float64
#  28  V28     1985 non-null   float64
#  29  Amount  1985 non-null   float64
#  30  Class   1985 non-null   float64
# dtypes: float64(30), int64(1)
# memory usage: 481.1 KB

# %%
data['Class'].value_counts()
# Out:
# Class
# 0.0    1983
# 1.0       2
# Name: count, dtype: int64

# %%
non_fraud = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
non_fraud.shape, fraud.shape
# Out:
# ((1983, 31), (2, 31))

# %%
non_fraud = non_fraud.sample(fraud.shape[0])
non_fraud.shape
# Out:
# (2, 31)

# %%
data = pd.concat([fraud, non_fraud], ignore_index=True)

# %%
import pandas as pd

# Assuming fraud and non_fraud are existing pandas DataFrames
data = fraud.append(non_fraud, ignore_index=True)

# Display the resulting DataFrame
print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-7b6bc2751975> in <cell line: 4>()
#       2
#       3 # Assuming fraud and non_fraud are existing pandas DataFrames
# ----> 4 data = fraud.append(non_fraud, ignore_index=True)
#       5
#       6 # Display the resulting DataFrame
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
data['Class'].value_counts()
# Out:
# Class
# 1.0    2
# 0.0    2
# Name: count, dtype: int64

# %%
X = data.drop('Class', axis = 1)
y = data['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5, random_state = 0, stratify = y)

# %%
X_train.shape, X_test.shape
# Out:
# ((2, 30), (2, 30))

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
X_train.shape
# Out:
# (2, 30)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
X_train.shape, X_test.shape
# Out:
# ((2, 30, 1), (2, 30, 1))

# %%
epochs = 20
model = Sequential()
model.add(Conv1D(32, 2, activation='relu', input_shape = X_train[0].shape))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(64, 2, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 29, 32)            96
#
#  batch_normalization (Batch  (None, 29, 32)            128
#  Normalization)
#
#  dropout (Dropout)           (None, 29, 32)            0
#
#  conv1d_1 (Conv1D)           (None, 28, 64)            4160
#
#  batch_normalization_1 (Bat  (None, 28, 64)            256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 28, 64)            0
#
#  flatten (Flatten)           (None, 1792)              0
#
#  dense (Dense)               (None, 64)                114752
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 119457 (466.63 KB)
# Trainable params: 119265 (465.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.0001), loss = 'binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 1.1159 - accuracy: 0.0000e+00 - val_loss: 0.4585 - val_accuracy: 0.5000
# Epoch 2/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2051 - accuracy: 1.0000 - val_loss: 0.4988 - val_accuracy: 0.5000
# Epoch 3/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.5359 - val_accuracy: 0.5000
# Epoch 4/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.3784 - accuracy: 0.5000 - val_loss: 0.5933 - val_accuracy: 0.5000
# Epoch 5/20
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 0.6396 - val_accuracy: 0.5000
# Epoch 6/20
# 1/1 [==============================] - 0s 69ms/step - loss: 4.7508e-04 - accuracy: 1.0000 - val_loss: 0.6825 - val_accuracy: 0.5000
# Epoch 7/20
# 1/1 [==============================] - 0s 73ms/step - loss: 4.6977e-04 - accuracy: 1.0000 - val_loss: 0.7258 - val_accuracy: 0.5000
# Epoch 8/20
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2658 - accuracy: 1.0000 - val_loss: 0.7686 - val_accuracy: 0.5000
# Epoch 9/20
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.8145 - val_accuracy: 0.5000
# Epoch 10/20
# 1/1 [==============================] - 0s 70ms/step - loss: 3.4004e-05 - accuracy: 1.0000 - val_loss: 0.8636 - val_accuracy: 0.5000
# Epoch 11/20
# 1/1 [==============================] - 0s 65ms/step - loss: 2.3391e-05 - accuracy: 1.0000 - val_loss: 0.9109 - val_accuracy: 0.5000
# Epoch 12/20
# 1/1 [==============================] - 0s 87ms/step - loss: 3.9239e-04 - accuracy: 1.0000 - val_loss: 0.9581 - val_accuracy: 0.5000
# Epoch 13/20
# 1/1 [==============================] - 0s 74ms/step - loss: 2.1073e-06 - accuracy: 1.0000 - val_loss: 1.0028 - val_accuracy: 0.5000
# Epoch 14/20
# 1/1 [==============================] - 0s 57ms/step - loss: 2.8615e-07 - accuracy: 1.0000 - val_loss: 1.0455 - val_accuracy: 0.5000
# Epoch 15/20
# 1/1 [==============================] - 0s 77ms/step - loss: 1.6035e-06 - accuracy: 1.0000 - val_loss: 1.0854 - val_accuracy: 0.5000
# Epoch 16/20
# 1/1 [==============================] - 0s 74ms/step - loss: 4.0698e-08 - accuracy: 1.0000 - val_loss: 1.1174 - val_accuracy: 0.5000
# Epoch 17/20
# 1/1 [==============================] - 0s 62ms/step - loss: 3.1911e-09 - accuracy: 1.0000 - val_loss: 1.1485 - val_accuracy: 0.5000
# Epoch 18/20
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3700e-08 - accuracy: 1.0000 - val_loss: 1.1780 - val_accuracy: 0.5000
# Epoch 19/20
# 1/1 [==============================] - 0s 37ms/step - loss: 2.9326e-07 - accuracy: 1.0000 - val_loss: 1.2066 - val_accuracy: 0.5000
# Epoch 20/20
# 1/1 [==============================] - 0s 40ms/step - loss: 4.8633e-08 - accuracy: 1.0000 - val_loss: 1.2335 - val_accuracy: 0.0000e+00

# %%
def plot_learningCurve(history, epoch):
  # Plot training & validation accuracy values
  epoch_range = range(1, epoch+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper left')
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range, history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper left')
  plt.show()

# %%
plot_learningCurve(history, epochs)

# %%
epochs = 50
model = Sequential()
model.add(Conv1D(32, 2, activation='relu', input_shape = X_train[0].shape))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Dropout(0.2))

model.add(Conv1D(64, 2, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(lr=0.0001), loss = 'binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=1)
plot_learningCurve(history, epochs)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 1/1 [==============================] - 5s 5s/step - loss: 2.6650 - accuracy: 0.0000e+00 - val_loss: 0.7563 - val_accuracy: 0.5000
# Epoch 2/50
# 1/1 [==============================] - 0s 71ms/step - loss: 1.0805 - accuracy: 0.0000e+00 - val_loss: 0.7403 - val_accuracy: 0.5000
# Epoch 3/50
# 1/1 [==============================] - 0s 79ms/step - loss: 1.7853 - accuracy: 0.5000 - val_loss: 0.7289 - val_accuracy: 0.5000
# Epoch 4/50
# 1/1 [==============================] - 0s 83ms/step - loss: 1.3361 - accuracy: 0.5000 - val_loss: 0.6897 - val_accuracy: 0.5000
# Epoch 5/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.8603 - accuracy: 0.5000 - val_loss: 0.6620 - val_accuracy: 0.5000
# Epoch 6/50
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4114 - accuracy: 1.0000 - val_loss: 0.6331 - val_accuracy: 0.5000
# Epoch 7/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1587 - accuracy: 1.0000 - val_loss: 0.6103 - val_accuracy: 0.5000
# Epoch 8/50
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4931 - accuracy: 0.5000 - val_loss: 0.5878 - val_accuracy: 0.5000
# Epoch 9/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.5721 - val_accuracy: 0.5000
# Epoch 10/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1096 - accuracy: 1.0000 - val_loss: 0.5660 - val_accuracy: 0.5000
# Epoch 11/50
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1196 - accuracy: 0.5000 - val_loss: 0.5803 - val_accuracy: 0.5000
# Epoch 12/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7818 - accuracy: 0.5000 - val_loss: 0.6160 - val_accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3057 - accuracy: 1.0000 - val_loss: 0.6551 - val_accuracy: 0.5000
# Epoch 14/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.7013 - val_accuracy: 0.5000
# Epoch 15/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.7528 - val_accuracy: 0.5000
# Epoch 16/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.8007 - val_accuracy: 0.5000
# Epoch 17/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8431 - val_accuracy: 0.5000
# Epoch 18/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2006 - accuracy: 1.0000 - val_loss: 0.9031 - val_accuracy: 0.5000
# Epoch 19/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.9589 - val_accuracy: 0.5000
# Epoch 20/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.0156 - val_accuracy: 0.5000
# Epoch 21/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0782 - accuracy: 1.0000 - val_loss: 1.0543 - val_accuracy: 0.5000
# Epoch 22/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.0900 - val_accuracy: 0.5000
# Epoch 23/50
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 1.1197 - val_accuracy: 0.5000
# Epoch 24/50
# 1/1 [==============================] - 0s 37ms/step - loss: 1.9385e-04 - accuracy: 1.0000 - val_loss: 1.1553 - val_accuracy: 0.5000
# Epoch 25/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.1980 - val_accuracy: 0.5000
# Epoch 26/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1648 - accuracy: 1.0000 - val_loss: 1.2587 - val_accuracy: 0.5000
# Epoch 27/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.3173 - val_accuracy: 0.5000
# Epoch 28/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 1.3711 - val_accuracy: 0.5000
# Epoch 29/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4177 - val_accuracy: 0.5000
# Epoch 30/50
# 1/1 [==============================] - 0s 37ms/step - loss: 6.8518e-05 - accuracy: 1.0000 - val_loss: 1.4602 - val_accuracy: 0.5000
# Epoch 31/50
# 1/1 [==============================] - 0s 37ms/step - loss: 2.4866e-05 - accuracy: 1.0000 - val_loss: 1.5053 - val_accuracy: 0.5000
# Epoch 32/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1800 - accuracy: 1.0000 - val_loss: 1.5141 - val_accuracy: 0.5000
# Epoch 33/50
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.5253 - val_accuracy: 0.5000
# Epoch 34/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5393 - val_accuracy: 0.5000
# Epoch 35/50
# 1/1 [==============================] - 0s 37ms/step - loss: 2.7685e-05 - accuracy: 1.0000 - val_loss: 1.5512 - val_accuracy: 0.5000
# Epoch 36/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.5637 - val_accuracy: 0.5000
# Epoch 37/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.5701 - val_accuracy: 0.5000
# Epoch 38/50
# 1/1 [==============================] - 0s 37ms/step - loss: 2.1226e-04 - accuracy: 1.0000 - val_loss: 1.5843 - val_accuracy: 0.5000
# Epoch 39/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.5927 - val_accuracy: 0.5000
# Epoch 40/50
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.6054 - val_accuracy: 0.5000
# Epoch 41/50
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.6179 - val_accuracy: 0.5000
# Epoch 42/50
# 1/1 [==============================] - 0s 35ms/step - loss: 4.3543e-05 - accuracy: 1.0000 - val_loss: 1.6279 - val_accuracy: 0.5000
# Epoch 43/50
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5956e-05 - accuracy: 1.0000 - val_loss: 1.6410 - val_accuracy: 0.5000
# Epoch 44/50
# 1/1 [==============================] - 0s 37ms/step - loss: 6.8381e-05 - accuracy: 1.0000 - val_loss: 1.6496 - val_accuracy: 0.5000
# Epoch 45/50
# 1/1 [==============================] - 0s 44ms/step - loss: 4.8599e-04 - accuracy: 1.0000 - val_loss: 1.6608 - val_accuracy: 0.5000
# Epoch 46/50
# 1/1 [==============================] - 0s 36ms/step - loss: 2.7784e-04 - accuracy: 1.0000 - val_loss: 1.6765 - val_accuracy: 0.5000
# Epoch 47/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2545 - accuracy: 1.0000 - val_loss: 1.7173 - val_accuracy: 0.5000
# Epoch 48/50
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 1.7423 - val_accuracy: 0.5000
# Epoch 49/50
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.7670 - val_accuracy: 0.5000
# Epoch 50/50
# 1/1 [==============================] - 0s 37ms/step - loss: 5.1208e-05 - accuracy: 1.0000 - val_loss: 1.7936 - val_accuracy: 0.5000
